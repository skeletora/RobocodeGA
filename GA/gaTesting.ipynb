# %% [markdown]
# # Current Issues
#
# - ~~Population generation needs to be fixed~~
#     - ~~Move pattern doesn't seem to be generating 5.  Might need to tweak random number generator parameters.~~
#     - ~~Need to fix "Move Dir" values to only be -1 or 1, no zeros~~
#     - ~~Fix mins and maxes so that mins aren't greater than maxes~~
# - ~~Need to update code to be modular in its methods~~
# - ~~Need to add a genome validator to ensure that algorithm is generating a valid population and that children are being produced with proper genomes~~
#     - ~~Need to add a check to ensure that minimums aren't greater than the maximums~~
#     - ~~Add check to ensure that "Move Dir" is either -1 or 1~~
# - Look into making sure that values are considered integers at the end of the cycle

# %%
import numpy as np

# %%
import geneticAlgorithm as ga

# %%
pop = ga.GA(numChildren = 3)
# Out:
# --------------------------------------------------
# STARTING INITIALIZATION
# Creating population with the following parameters:
# Population size: 10
# Initial population: None
# Number of parents per generation: 5
# Number of children per generation: 3
# --------------------------------------------------
# CREATING A POPULATION
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# FINISHED MAKING POPULATION
# --------------------------------------------------
# FINISHED INITIALIZATION
# --------------------------------------------------

# %%
pop.children
# Out:
#   Score Move Pattern Min Dist Max Dist Min Rot Max Rot Move Delay Move Dir  \
# 0   NaN          NaN      NaN      NaN     NaN     NaN        NaN      NaN
# 1   NaN          NaN      NaN      NaN     NaN     NaN        NaN      NaN
# 2   NaN          NaN      NaN      NaN     NaN     NaN        NaN      NaN
#
#   Move Vel Bullet Pattern Targeting Pattern Probability
# 0      NaN            NaN               NaN         NaN
# 1      NaN            NaN               NaN         NaN
# 2      NaN            NaN               NaN         NaN

# %%
pop.PrintPopStatus()
# Out:
# Current Generation: 0
#    Score  Move Pattern  Min Dist  Max Dist  Min Rot  Max Rot  Move Delay  \
# 0      0             1        41       100       13       13           6
# 1      0             4        74        74      281      283           3
# 2      0             2        71        71      142      351           3
# 3      0             2        61        61       12      215           3
# 4      0             4        18        18      151      315           2
# 5      0             2        54        54      335      335           0
# 6      0             5         7         7      183      291           2
# 7      0             0        14        14       76       76           7
# 8      0             1        32        72      168      168           7
# 9      0             3        22        22       12       12           2
#
#    Move Dir  Move Vel  Bullet Pattern  Targeting Pattern  Probability
# 0        -1         8               2                  3            0
# 1        -1         2               1                  0            0
# 2        -1         2               3                  2            0
# 3         1         5               4                  0            0
# 4         1         6               2                  2            0
# 5         1         4               4                  0            0
# 6        -1         1               2                  3            0
# 7         1         2               1                  1            0
# 8         1         5               4                  2            0
# 9         1         7               2                  3            0

# %%
pop.SurvivorSelection()
# Out:
# --------------------------------------------------
# INSIDE SURVIVOR SELECTION
# END OF SURVIVOR SELECTION
# --------------------------------------------------

# %%
pop.ParentSelection()
# Out:
# --------------------------------------------------
# INSIDE PARENT SELECTION
# --------------------------------------------------
# INSIDE CALCPROB
# --------------------------------------------------
# INSIDE SCORE BASED PROBABILITY
# END OF SCORE BASED PROBABILITY
# --------------------------------------------------
# END OF CALCPROB
# --------------------------------------------------
# --------------------------------------------------
# INSIDE STOCHASTIC UNIVERSAL SAMPLING
# Selecting 5 Parents
# Cumulative probability is: [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6, 0.7, 0.7999999999999999, 0.8999999999999999, 0.9999999999999999]
# r is: 0.023350028432215477
# r is: 0.2233500284322155
# r is: 0.4233500284322155
# r is: 0.6233500284322155
# r is: 0.8233500284322155
# r is: 1.0233500284322155
# The parents are:
# [0, 2, 4, 6, 8]
# END OF STOCHASTIC UNIVERSAL SAMPLING
# --------------------------------------------------
# END OF PARENT SELECTION
# --------------------------------------------------

# %%
pop.Recombination(recombMethod = "weighted average", weight = 0.75)
# Out:
# --------------------------------------------------
# INSIDE RECOMBINATION
# Pair: [0, 6]
# childCount: 0
# --------------------------------------------------
# INSIDE SIMPLE ARITHMETIC RECOMBINATION
# Parent 1 is: 0
# Parent 2 is: 6
# Weight is: 0.75
# Par1 is: [1.0, 41.0, 100.0, 13.0, 13.0, 6.0, -1.0, 8.0, 2.0, 3.0]
# Par2 is: [5.0, 7.0, 7.0, 183.0, 291.0, 2.0, -1.0, 1.0, 2.0, 3.0]
# k is: 5
# child1 is: [1.0, 41.0, 100.0, 13.0, 13.0, 3.0, -1.0, 2.75, 2.0, 3.0]
# child2 is: [5.0, 7.0, 7.0, 183.0, 291.0, 5.0, -1.0, 6.25, 2.0, 3.0]
# END OF SIMPLE ARITHMETIC RECOMBINATION
# --------------------------------------------------
# Pair: [6, 8]
# childCount: 2
# --------------------------------------------------
# INSIDE SIMPLE ARITHMETIC RECOMBINATION
# Parent 1 is: 6
# Parent 2 is: 8
# Weight is: 0.75
# Par1 is: [5.0, 7.0, 7.0, 183.0, 291.0, 2.0, -1.0, 1.0, 2.0, 3.0]
# Par2 is: [1.0, 32.0, 72.0, 168.0, 168.0, 7.0, 1.0, 5.0, 4.0, 2.0]
# k is: 4
# child1 is: [5.0, 7.0, 7.0, 183.0, 198.75, 5.75, 0.5, 4.0, 3.5, 2.25]
# child2 is: [1.0, 32.0, 72.0, 168.0, 260.25, 3.25, -0.5, 2.0, 2.5, 2.75]
# END OF SIMPLE ARITHMETIC RECOMBINATION
# --------------------------------------------------
# --------------------------------------------------
# INSIDE FIX GENOME
# Rounding 0 at (0, Score)
# The value of skipClamp is: True
# Rounding 1.0 at (0, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 41.0 at (0, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 41 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 100.0 at (0, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 100 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 13.0 at (0, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 13 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 13.0 at (0, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 13 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding -1.0 at (0, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: -1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.75 at (0, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (0, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (0, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (1, Score)
# The value of skipClamp is: True
# Rounding 5.0 at (1, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 5 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 7.0 at (1, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 7 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 7.0 at (1, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 7 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 183.0 at (1, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 183 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 291.0 at (1, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 291 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 5.0 at (1, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 5 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding -1.0 at (1, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: -1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 6.25 at (1, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 6 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (1, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (1, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (1, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (2, Score)
# The value of skipClamp is: True
# Rounding 5.0 at (2, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 5 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 7.0 at (2, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 7 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 7.0 at (2, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 7 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 183.0 at (2, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 183 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 198.75 at (2, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 199 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 5.75 at (2, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 6 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0.5 at (2, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 4.0 at (2, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 4 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.5 at (2, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 4 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.25 at (2, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (2, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# END OF FIX GENOME
# --------------------------------------------------
# END OF RECOMBINATION
# --------------------------------------------------

# %%
pop.children
# Out:
#    Score  Move Pattern  Min Dist  Max Dist  Min Rot  Max Rot  Move Delay  \
# 0      0             1        41       100       13       13           3
# 1      0             5         7         7      183      291           5
# 2      0             5         7         7      183      199           6
#
#    Move Dir  Move Vel  Bullet Pattern  Targeting Pattern  Probability
# 0        -1         3               2                  3            0
# 1         1         6               2                  3            0
# 2         1         4               4                  2            0

# %%
pop.Mutate(mutationRate = 0.5, mutationVariance = 1.0)
# Out:
# --------------------------------------------------
# INSIDE MUTATE
# Mutation rate is: 0.5
# Mutation variation is: 1.0
# --------------------------------------------------
# INSIDE GAUSSIAN MUTATION
# Before mutation of child 2 in category Move Pattern: 5
# After mutation of child 2 in category Move Pattern: 5.134029969100279
# Before mutation of child 2 in category Min Dist: 7
# After mutation of child 2 in category Min Dist: 5.81549783529851
# Before mutation of child 2 in category Max Dist: 7
# After mutation of child 2 in category Max Dist: 6.9664072134750255
# Before mutation of child 2 in category Min Rot: 183
# After mutation of child 2 in category Min Rot: 182.69361673612593
# Before mutation of child 2 in category Max Rot: 199
# After mutation of child 2 in category Max Rot: 198.14293619295972
# Before mutation of child 2 in category Move Delay: 6
# After mutation of child 2 in category Move Delay: 6.011760274213
# Before mutation of child 2 in category Move Dir: 1
# After mutation of child 2 in category Move Dir: 1.7744796378234713
# Before mutation of child 2 in category Move Vel: 4
# After mutation of child 2 in category Move Vel: 4.469162836874045
# Before mutation of child 2 in category Bullet Pattern: 4
# After mutation of child 2 in category Bullet Pattern: 4.997345354885469
# Before mutation of child 2 in category Targeting Pattern: 2
# After mutation of child 2 in category Targeting Pattern: 3.671471435916634
# END OF GAUSSIAN MUTATION
# --------------------------------------------------
# --------------------------------------------------
# INSIDE FIX GENOME
# Rounding 0 at (0, Score)
# The value of skipClamp is: True
# Rounding 1.0 at (0, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 41.0 at (0, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 41 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 100.0 at (0, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 100 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 13.0 at (0, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 13 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 13.0 at (0, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 13 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding -1.0 at (0, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: -1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (0, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (0, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (1, Score)
# The value of skipClamp is: True
# Rounding 5.0 at (1, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 5 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 7.0 at (1, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 7 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 7.0 at (1, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 7 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 183.0 at (1, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 183 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 291.0 at (1, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 291 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 5.0 at (1, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 5 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (1, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 6.0 at (1, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 6 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (1, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (1, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (1, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (2, Score)
# The value of skipClamp is: True
# Rounding 5.134029969100279 at (2, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 5 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 5.81549783529851 at (2, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 6 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 6.9664072134750255 at (2, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 7 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 182.69361673612593 at (2, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 183 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 198.14293619295972 at (2, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 198 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 6.011760274213 at (2, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 6 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.7744796378234713 at (2, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 4.469162836874045 at (2, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 4 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 4.997345354885469 at (2, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 5 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.671471435916634 at (2, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 4 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (2, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# END OF FIX GENOME
# --------------------------------------------------
# END OF MUTATE
# --------------------------------------------------

# %%
pop.children
# Out:
#    Score  Move Pattern  Min Dist  Max Dist  Min Rot  Max Rot  Move Delay  \
# 0      0           1.0      41.0     100.0     13.0     13.0         3.0
# 1      0           5.0       7.0       7.0    183.0    291.0         5.0
# 2      0           5.0       6.0       7.0    183.0    198.0         6.0
#
#    Move Dir  Move Vel  Bullet Pattern  Targeting Pattern  Probability
# 0       1.0       3.0             2.0                3.0            0
# 1      -1.0       6.0             2.0                3.0            0
# 2       1.0       4.0             4.0                3.0            0

# %%
pop.SurvivorSelection()
# Out:
# --------------------------------------------------
# INSIDE SURVIVOR SELECTION
# --------------------------------------------------
# INSIDE GENITOR
# END OF GENITOR
# --------------------------------------------------
# END OF SURVIVOR SELECTION
# --------------------------------------------------

# %%
pop.PrintPopStatus()
# Out:
# Current Generation: 1
#    Score  Move Pattern  Min Dist  Max Dist  Min Rot  Max Rot  Move Delay  \
# 0      0           1.0      41.0     100.0     13.0     13.0         6.0
# 1      0           4.0      74.0      74.0    281.0    283.0         3.0
# 2      0           2.0      71.0      71.0    142.0    351.0         3.0
# 3      0           2.0      61.0      61.0     12.0    215.0         3.0
# 4      0           4.0      18.0      18.0    151.0    315.0         2.0
# 5      0           2.0      54.0      54.0    335.0    335.0         0.0
# 6      0           5.0       7.0       7.0    183.0    291.0         2.0
# 7      0           1.0      41.0     100.0     13.0     13.0         3.0
# 8      0           5.0       7.0       7.0    183.0    291.0         5.0
# 9      0           5.0       6.0       7.0    183.0    198.0         6.0
#
#    Move Dir  Move Vel  Bullet Pattern  Targeting Pattern  Probability
# 0      -1.0       8.0             2.0                3.0          0.1
# 1      -1.0       2.0             1.0                0.0          0.1
# 2      -1.0       2.0             3.0                2.0          0.1
# 3       1.0       5.0             4.0                0.0          0.1
# 4       1.0       6.0             2.0                2.0          0.1
# 5       1.0       4.0             4.0                0.0          0.1
# 6      -1.0       1.0             2.0                3.0          0.1
# 7       1.0       3.0             2.0                3.0          0.0
# 8      -1.0       6.0             2.0                3.0          0.0
# 9       1.0       4.0             4.0                3.0          0.0

# %%
pop.Generation()
# Out:
# --------------------------------------------------
# INSIDE FITNESS FUNCTION
# Cannot run algorithm without a driver.
# END OF FITNESS FUNCTION
# --------------------------------------------------
# --------------------------------------------------
# INSIDE SURVIVOR SELECTION
# --------------------------------------------------
# INSIDE GENITOR
# END OF GENITOR
# --------------------------------------------------
# END OF SURVIVOR SELECTION
# --------------------------------------------------
# --------------------------------------------------
# INSIDE PARENT SELECTION
# --------------------------------------------------
# INSIDE CALCPROB
# --------------------------------------------------
# INSIDE SCORE BASED PROBABILITY
# END OF SCORE BASED PROBABILITY
# --------------------------------------------------
# END OF CALCPROB
# --------------------------------------------------
# --------------------------------------------------
# INSIDE STOCHASTIC UNIVERSAL SAMPLING
# Selecting 5 Parents
# Cumulative probability is: [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6, 0.7, 0.7999999999999999, 0.8999999999999999, 0.9999999999999999]
# r is: 0.17791355305956114
# r is: 0.37791355305956115
# r is: 0.5779135530595612
# r is: 0.7779135530595611
# r is: 0.9779135530595611
# r is: 1.177913553059561
# The parents are:
# [1, 3, 5, 7, 9]
# END OF STOCHASTIC UNIVERSAL SAMPLING
# --------------------------------------------------
# END OF PARENT SELECTION
# --------------------------------------------------
# --------------------------------------------------
# INSIDE RECOMBINATION
# Pair: [9, 1]
# childCount: 0
# --------------------------------------------------
# INSIDE SPLICE GENOME
# Parent 1 is: 9
# Parent 2 is: 1
# Par1 is: [5.0, 6.0, 7.0, 183.0, 198.0, 6.0, 1.0, 4.0, 4.0, 3.0]
# Par2 is: [4.0, 74.0, 74.0, 281.0, 283.0, 3.0, -1.0, 2.0, 1.0, 0.0]
# k is: 0
# child1 is: [4.0, 74.0, 74.0, 281.0, 283.0, 3.0, -1.0, 2.0, 1.0, 0.0]
# child2 is: [5.0, 6.0, 7.0, 183.0, 198.0, 6.0, 1.0, 4.0, 4.0, 3.0]
# END OF SPLICE GENOME
# --------------------------------------------------
# Pair: [5, 7]
# childCount: 2
# --------------------------------------------------
# INSIDE SPLICE GENOME
# Parent 1 is: 5
# Parent 2 is: 7
# Par1 is: [2.0, 54.0, 54.0, 335.0, 335.0, 0.0, 1.0, 4.0, 4.0, 0.0]
# Par2 is: [1.0, 41.0, 100.0, 13.0, 13.0, 3.0, 1.0, 3.0, 2.0, 3.0]
# k is: 3
# child1 is: [2.0, 54.0, 54.0, 13.0, 13.0, 3.0, 1.0, 3.0, 2.0, 3.0]
# child2 is: [1.0, 41.0, 100.0, 335.0, 335.0, 0.0, 1.0, 4.0, 4.0, 0.0]
# END OF SPLICE GENOME
# --------------------------------------------------
# --------------------------------------------------
# INSIDE FIX GENOME
# Rounding 0 at (0, Score)
# The value of skipClamp is: True
# Rounding 4.0 at (0, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 4 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 74.0 at (0, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 74 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 74.0 at (0, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 74 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 281.0 at (0, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 281 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 283.0 at (0, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 283 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding -1.0 at (0, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: -1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (0, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (0, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0.0 at (0, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (0, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (1, Score)
# The value of skipClamp is: True
# Rounding 5.0 at (1, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 5 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 6.0 at (1, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 6 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 7.0 at (1, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 7 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 183.0 at (1, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 183 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 198.0 at (1, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 198 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 6.0 at (1, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 6 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (1, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 4.0 at (1, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 4 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 4.0 at (1, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 4 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (1, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (1, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (2, Score)
# The value of skipClamp is: True
# Rounding 2.0 at (2, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 54.0 at (2, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 54 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 54.0 at (2, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 54 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 13.0 at (2, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 13 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 13.0 at (2, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 13 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (2, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (2, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (2, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (2, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (2, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (2, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# END OF FIX GENOME
# --------------------------------------------------
# END OF RECOMBINATION
# --------------------------------------------------
# --------------------------------------------------
# INSIDE MUTATE
# Mutation rate is: 0.05
# Mutation variation is: 1.0
# --------------------------------------------------
# INSIDE FIX GENOME
# Rounding 0 at (0, Score)
# The value of skipClamp is: True
# Rounding 4.0 at (0, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 4 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 74.0 at (0, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 74 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 74.0 at (0, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 74 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 281.0 at (0, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 281 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 283.0 at (0, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 283 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (0, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (0, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (0, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0.0 at (0, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (0, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (1, Score)
# The value of skipClamp is: True
# Rounding 5.0 at (1, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 5 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 6.0 at (1, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 6 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 7.0 at (1, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 7 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 183.0 at (1, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 183 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 198.0 at (1, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 198 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 6.0 at (1, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 6 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (1, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 4.0 at (1, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 4 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 4.0 at (1, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 4 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (1, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (1, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (2, Score)
# The value of skipClamp is: True
# Rounding 2.0 at (2, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 54.0 at (2, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 54 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 54.0 at (2, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 54 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 13.0 at (2, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 13 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 13.0 at (2, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 13 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (2, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding -1.0 at (2, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: -1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (2, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (2, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (2, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (2, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# END OF FIX GENOME
# --------------------------------------------------
# END OF MUTATE
# --------------------------------------------------
