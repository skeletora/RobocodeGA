# %% [markdown]
# # Current Issues
#
# - ~~Population generation needs to be fixed~~
#     - ~~Move pattern doesn't seem to be generating 5.  Might need to tweak random number generator parameters.~~
#     - ~~Need to fix "Move Dir" values to only be -1 or 1, no zeros~~
#     - ~~Fix mins and maxes so that mins aren't greater than maxes~~
# - ~~Need to update code to be modular in its methods~~
# - ~~Need to add a genome validator to ensure that algorithm is generating a valid population and that children are being produced with proper genomes~~
#     - ~~Need to add a check to ensure that minimums aren't greater than the maximums~~
#     - ~~Add check to ensure that "Move Dir" is either -1 or 1~~
# - Look into making sure that values are considered integers at the end of the cycle

# %%
import numpy as np

# %%
import os

# %%
import geneticAlgorithm as ga

# %%
pop = ga.GA(numChildren = 3)

# %%
pop.children
# Out:
#   Score Move Pattern Min Dist Max Dist Min Rot Max Rot Move Delay Move Dir  \
# 0   NaN          NaN      NaN      NaN     NaN     NaN        NaN      NaN
# 1   NaN          NaN      NaN      NaN     NaN     NaN        NaN      NaN
# 2   NaN          NaN      NaN      NaN     NaN     NaN        NaN      NaN
#
#   Move Vel Bullet Pattern Targeting Pattern Probability
# 0      NaN            NaN               NaN         NaN
# 1      NaN            NaN               NaN         NaN
# 2      NaN            NaN               NaN         NaN

# %%
pop.PrintPopStatus()
# Out:
# Current Generation: 0
#    Score  Move Pattern  Min Dist  Max Dist  Min Rot  Max Rot  Move Delay  \
# 0      0             2        79        81      322      341           6
# 1      0             3         8        64      150      168           2
# 2      0             5        59        59      185      185           1
# 3      0             1        58        58       23      304          10
# 4      0             3         7        78        7      289           2
# 5      0             3        84        86      244      244           2
# 6      0             0        54        54      134      166           4
# 7      0             3        58        58      257      257           3
# 8      0             2        74        74       20       20           0
# 9      0             0        73        77      217      217           3
#
#    Move Dir  Move Vel  Bullet Pattern  Targeting Pattern  Probability
# 0         1         4               4                  2            0
# 1        -1         5               0                  0            0
# 2         1         4               2                  1            0
# 3         1         1               2                  3            0
# 4        -1         0               1                  3            0
# 5         1         1               1                  3            0
# 6        -1         2               2                  0            0
# 7         1         8               2                  1            0
# 8        -1         7               2                  3            0
# 9         1         6               0                  3            0

# %%
pop.SurvivorSelection()

# %%
pop.ParentSelection()

# %%
pop.Recombination(recombMethod = "weighted average", weight = 0.75)
# Out:
# --------------------------------------------------
# INSIDE FIX GENOME
# Rounding 0 at (0, Score)
# The value of skipClamp is: True
# Rounding 2.0 at (0, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 79.0 at (0, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 79 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 81.0 at (0, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 81 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 85.75 at (0, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 86 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 302.0 at (0, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 302 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding -0.5 at (0, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (0, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.75 at (0, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.75 at (0, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (0, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (1, Score)
# The value of skipClamp is: True
# Rounding 3.0 at (1, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 7.0 at (1, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 7 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 78.0 at (1, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 78 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 243.25 at (1, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 243 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 328.0 at (1, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 328 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 5.0 at (1, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 5 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0.5 at (1, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (1, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.25 at (1, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.25 at (1, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (1, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (2, Score)
# The value of skipClamp is: True
# Rounding 0.0 at (2, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 57.75 at (2, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 58 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 57.75 at (2, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 58 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 172.25 at (2, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 172 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 180.25 at (2, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 180 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.75 at (2, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0.5 at (2, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.5 at (2, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 4 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (2, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0.75 at (2, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (2, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# END OF FIX GENOME
# --------------------------------------------------

# %%
pop.children
# Out:
#    Score  Move Pattern  Min Dist  Max Dist  Min Rot  Max Rot  Move Delay  \
# 0      0             2        79        81       86      302           3
# 1      0             3         7        78      243      328           5
# 2      0             0        58        58      172      180           2
#
#    Move Dir  Move Vel  Bullet Pattern  Targeting Pattern  Probability
# 0         1         1               2                  3            0
# 1        -1         3               3                  2            0
# 2        -1         4               2                  1            0

# %%
pop.Mutate(mutationRate = 0.5, mutationVariance = 1.0)
# Out:
# --------------------------------------------------
# INSIDE FIX GENOME
# Rounding 0 at (0, Score)
# The value of skipClamp is: True
# Rounding 1.1352370752158718 at (0, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 79.47862864441286 at (0, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 79 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 80.65654389070157 at (0, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 81 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 85.81620069800324 at (0, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 86 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 303.16461560507105 at (0, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 303 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0.8639733802602536 at (0, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.7492060952250725 at (0, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.654839089750902 at (0, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.7234761075291367 at (0, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 4.451662742882922 at (0, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 4 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (0, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (1, Score)
# The value of skipClamp is: True
# Rounding 3.0 at (1, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 7.0 at (1, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 7 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 78.0 at (1, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 78 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 243.0 at (1, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 243 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 328.0 at (1, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 328 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 5.0 at (1, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 5 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding -1.0 at (1, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: -1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (1, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (1, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (1, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (1, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (2, Score)
# The value of skipClamp is: True
# Rounding -1.7326470033547396 at (2, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: -2 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 57.89555183991043 at (2, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 58 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 57.32529574597525 at (2, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 57 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 172.08294320784282 at (2, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 172 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 179.79947428420485 at (2, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 180 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.846848659554267 at (2, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding -1.2449472585396721 at (2, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: -1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.246276515441303 at (2, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.7450178777609495 at (2, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0.7571825870752379 at (2, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (2, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# END OF FIX GENOME
# --------------------------------------------------

# %%
pop.children
# Out:
#    Score  Move Pattern  Min Dist  Max Dist  Min Rot  Max Rot  Move Delay  \
# 0      0           1.0      79.0      81.0     86.0    303.0         1.0
# 1      0           3.0       7.0      78.0    243.0    328.0         5.0
# 2      0           0.0      58.0      57.0    172.0    180.0         2.0
#
#    Move Dir  Move Vel  Bullet Pattern  Targeting Pattern  Probability
# 0      -1.0       2.0             2.0                3.0            0
# 1      -1.0       3.0             3.0                2.0            0
# 2      -1.0       3.0             3.0                1.0            0

# %%
pop.SurvivorSelection()

# %%
pop.PrintPopStatus()
# Out:
# Current Generation: 1
#    Score  Move Pattern  Min Dist  Max Dist  Min Rot  Max Rot  Move Delay  \
# 0      0           2.0      79.0      81.0    322.0    341.0         6.0
# 1      0           3.0       8.0      64.0    150.0    168.0         2.0
# 2      0           5.0      59.0      59.0    185.0    185.0         1.0
# 3      0           1.0      58.0      58.0     23.0    304.0        10.0
# 4      0           3.0       7.0      78.0      7.0    289.0         2.0
# 5      0           3.0      84.0      86.0    244.0    244.0         2.0
# 6      0           0.0      54.0      54.0    134.0    166.0         4.0
# 7      0           1.0      79.0      81.0     86.0    303.0         1.0
# 8      0           3.0       7.0      78.0    243.0    328.0         5.0
# 9      0           0.0      58.0      57.0    172.0    180.0         2.0
#
#    Move Dir  Move Vel  Bullet Pattern  Targeting Pattern  Probability
# 0       1.0       4.0             4.0                2.0          0.1
# 1      -1.0       5.0             0.0                0.0          0.1
# 2       1.0       4.0             2.0                1.0          0.1
# 3       1.0       1.0             2.0                3.0          0.1
# 4      -1.0       0.0             1.0                3.0          0.1
# 5       1.0       1.0             1.0                3.0          0.1
# 6      -1.0       2.0             2.0                0.0          0.1
# 7      -1.0       2.0             2.0                3.0          0.0
# 8      -1.0       3.0             3.0                2.0          0.0
# 9      -1.0       3.0             3.0                1.0          0.0

# %%
pop.Generation(driverFile = 'hi')
# Out:
# --------------------------------------------------
# INSIDE FITNESS FUNCTION
# 2.0,79.0,81.0,322.0,341.0,6.0,1.0,4.0:2.0:4.0
# 3.0,8.0,64.0,150.0,168.0,2.0,-1.0,5.0:0.0:0.0
# 5.0,59.0,59.0,185.0,185.0,1.0,1.0,4.0:1.0:2.0
# 1.0,58.0,58.0,23.0,304.0,10.0,1.0,1.0:3.0:2.0
# 3.0,7.0,78.0,7.0,289.0,2.0,-1.0,0.0:3.0:1.0
# 3.0,84.0,86.0,244.0,244.0,2.0,1.0,1.0:3.0:1.0
# 0.0,54.0,54.0,134.0,166.0,4.0,-1.0,2.0:0.0:2.0
# 1.0,79.0,81.0,86.0,303.0,1.0,-1.0,2.0:3.0:2.0
# 3.0,7.0,78.0,243.0,328.0,5.0,-1.0,3.0:2.0:3.0
# 0.0,58.0,57.0,172.0,180.0,2.0,-1.0,3.0:1.0:3.0
# Results are:
# ['', '', '', '', '', '', '', '', '', '']
# END OF FITNESS FUNCTION
# --------------------------------------------------
# --------------------------------------------------
# INSIDE FIX GENOME
# Rounding 0 at (0, Score)
# The value of skipClamp is: True
# Rounding 0.0 at (0, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 58.0 at (0, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 58 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 57.0 at (0, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 57 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 172.0 at (0, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 172 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 180.0 at (0, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 180 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (0, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding -1.0 at (0, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: -1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (0, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (1, Score)
# The value of skipClamp is: True
# Rounding 1.0 at (1, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 79.0 at (1, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 79 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 81.0 at (1, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 81 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 86.0 at (1, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 86 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 303.0 at (1, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 303 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (1, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding -1.0 at (1, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: -1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (1, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (1, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (1, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (1, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (2, Score)
# The value of skipClamp is: True
# Rounding 0.0 at (2, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 58.0 at (2, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 58 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 57.0 at (2, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 57 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 150.0 at (2, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 150 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 168.0 at (2, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 168 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (2, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding -1.0 at (2, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: -1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 5.0 at (2, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 5 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0.0 at (2, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0.0 at (2, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (2, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# END OF FIX GENOME
# --------------------------------------------------
# --------------------------------------------------
# INSIDE FIX GENOME
# Rounding 0 at (0, Score)
# The value of skipClamp is: True
# Rounding 0.0 at (0, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 58.0 at (0, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 58 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 57.0 at (0, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 57 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 172.0 at (0, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 172 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 180.0 at (0, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 180 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (0, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (0, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 3.0 at (0, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 3 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (0, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (1, Score)
# The value of skipClamp is: True
# Rounding 1.0 at (1, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 79.0 at (1, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 79 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 81.0 at (1, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 81 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 86.0 at (1, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 86 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 303.0 at (1, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 303 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (1, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (1, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (1, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (1, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 1.0 at (1, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 1 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (1, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# Rounding 0 at (2, Score)
# The value of skipClamp is: True
# Rounding 0.0 at (2, Move Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [0, 5]
# END OF CLAMP
# --------------------------------------------------
# Rounding 58.0 at (2, Min Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 58 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 57.0 at (2, Max Dist)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 57 and [min, max]: [0, 100]
# END OF CLAMP
# --------------------------------------------------
# Rounding 150.0 at (2, Min Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 150 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 168.0 at (2, Max Rot)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 168 and [min, max]: [0, 360]
# END OF CLAMP
# --------------------------------------------------
# Rounding 2.0 at (2, Move Delay)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 2 and [min, max]: [0, 10]
# END OF CLAMP
# --------------------------------------------------
# Rounding -1.0 at (2, Move Dir)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: -1 and [min, max]: [-1, 1]
# END OF CLAMP
# --------------------------------------------------
# Rounding 5.0 at (2, Move Vel)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 5 and [min, max]: [0, 8]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0.0 at (2, Bullet Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [0, 4]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0.0 at (2, Targeting Pattern)
# The value of skipClamp is: False
# --------------------------------------------------
# INSIDE CLAMP
# value: 0 and [min, max]: [0, 3]
# END OF CLAMP
# --------------------------------------------------
# Rounding 0 at (2, Probability)
# The value of skipClamp is: True
# Found a match! It's Min Dist and Max Dist
# Found a match! It's Min Rot and Max Rot
# END OF FIX GENOME
# --------------------------------------------------

# %%
filePath = os.getcwd()
filePath
# Out:
# 'C:\\Users\\becky\\Documents\\school\\Edinboro\\classes\\Senior Year\\Fall 2020\\Independent Study\\RobocodeGA\\GA'

# %%
filePath[:len(filePath) - 2]
# Out:
# 'C:\\Users\\becky\\Documents\\school\\Edinboro\\classes\\Senior Year\\Fall 2020\\Independent Study\\RobocodeGA\\'

# %%
filePath = filePath[:len(filePath) - 2] + "DanCode"
filePath
# Out:
# 'C:\\Users\\becky\\Documents\\school\\Edinboro\\classes\\Senior Year\\Fall 2020\\Independent Study\\RobocodeGA\\DanCode'

# %%
MOVEMENT_OPTIONS = {"Move Pattern" : [0, 5],   "Min Dist" : [0, 100], "Max Dist"   : [0, 100],
                    "Min Rot"      : [0, 360], "Max Rot"  : [0, 360], "Move Delay" : [0, 10],
                    "Move Dir"     : [-1, 1],  "Move Vel" : [0, 8]}

# %%
mvKey = list(MOVEMENT_OPTIONS.keys())
mvKey
# Out:
# ['Move Pattern',
#  'Min Dist',
#  'Max Dist',
#  'Min Rot',
#  'Max Rot',
#  'Move Delay',
#  'Move Dir',
#  'Move Vel']
